# %%
import requests
import json

url = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_rows"
url_save = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_save_work_lesson_subject"

cookie = 'ssuz_sessionid=li2tlhtjj8f90adwti8n63unt7it82th'
name = ''
les_id = 0

spisok = [
    {"group": "питпм_исп221а", "student_id": 70002, "group_id": 4649,"subject_id":"6132", "id":0},#0
    {"group": "питпм_исп221ав", "student_id": 70027, "group_id": 4659,"subject_id":"6132", "id":1},#1
    {"group": "рмп_исп320а", "student_id": 61655, "group_id": 4078,"subject_id":"6133", "id":2},#2
    {"group": "рмп_исп320ав", "student_id": 61683, "group_id": 4079,"subject_id":"6133", "id":3},#3
    {"group": "питпм_исп320п", "student_id": 61684, "group_id": 4080,"subject_id":"6132", "id":4},#4
    {"group": "питпм_исп320пв", "student_id": 61709, "group_id": 4081,"subject_id":"6132", "id":5},#5
    {"group": "ркис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6189", "id":6},#6
    {"group": "тис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6190", "id":7},#7
    {"group": "ркис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6189", "id":8},#8
    {"group": "тис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6190", "id":9},#9
    {"group": "опбд_сис221", "student_id": 69973, "group_id": 4644,"subject_id":"5548", "id":10},#10
    {"group": "опбд_сис221в", "student_id": 69998, "group_id": 4653,"subject_id":"5548", "id":11},#11
    # {"group": "обвп_исп419р", "student_id": 48698, "group_id": 2848,"subject_id":"8010", "id":12},#12
    # {"group": "обвп_исп419рв", "student_id": 49324, "group_id": 2945,"subject_id":"8010", "id":13},#13
]

payload = {
    "unit_id": 22,
    "period_id":	30,
    "date_from":	"2022-09-01T00:00:00",
    "date_to":	"03.11.2022",
    "practical":	"",
    "slave_mode":	"",
    "month":	"",
    "group_id":	spisok[1]['group_id'],
    "subject":	"0",
    "subject_gen_pr_id":	"0",
    "exam_subject_id":	"0",
    "subject_sub_group_obj":	"{\"subject_id\": 6132}",
    "subject_id":	"6132",
    "view_lessons":	"false"
}
headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}

response = requests.post(url, headers=headers, data=payload)

# print(response.json())
data = response.json()
# [0].lessons
# list
# print(data['rows'][0]['lessons'])

rows = data['rows'][0]['lessons']
# for i in rows:
#   print(i['id'])

try:
    with open('parse2.txt', encoding="utf-8") as file:
        lines = file.readlines()
        # print(len(lines))
        for i in range(len(lines)):
            name = lines[i]
            les_id = rows[i]['id']
            payload_save = {
                "lesson_id": les_id,
                "student_id": spisok[1]['student_id'],
                "unit_id": "22",
                "period_id": "30",
                "date_from": "2022-09-01T00:00:00",
                "date_to": "03.11.2022",
                "practical": "",
                "slave_mode": "1",
                "month": "",
                "group_id": spisok[1]['group_id'],
                "subject": "0",
                "subject_gen_pr_id": "0",
                "exam_subject_id": "0",
                "subject_sub_group_obj":	"{\"subject_id\": "+spisok[1]['subject_id']+"}",
                "subject_id": "6132",
                "view_lessons": "false",
                "lesson_subject": name
            }

            response = requests.post(
                url_save, headers=headers, data=payload_save)

            data = response.json()

            print(i, response.status_code, data)
            # print(data)

            # print(lines[i], rows[i]['id'])
        #   text =i.rstrip()
        #   print(text)
except Exception as e:
    print(e)

finally:
    file.close()

# %%
import requests
import json

url = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_save_work_lesson_subject"
cookie = 'ssuz_sessionid=zys0t1yl7z0y9lh5m8amjngjlzf8tsc3; ssuz_sessionid=ecagck56uh0y2bjphnpjeu5lvmpdj2mp'
name = ''
les_id = 0

payload = {
  "lesson_id":2787162,
"student_id":"70002",
"unit_id":"22",
"period_id":"30",
"date_from":"2022-09-01T00:00:00",
"date_to":"03.11.2022",
"practical":"",
"slave_mode":"1",
"month":"",
"group_id":"4649",
"subject":"0",
"subject_gen_pr_id":"0",
"exam_subject_id":"0",
"subject_sub_group_obj":"{\"subject_id\": 6132}",
"subject_id":"6132",
"view_lessons":"false",
"lesson_subject":"names"
}
headers = {
  'Host': 'ssuz.vip.edu35.ru',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
  'Accept': '*/*',
  'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
  'Accept-Encoding': 'gzip, deflate, br',
  'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
  'Cookie': cookie
}
les_id = "2787162"
name = 'Тести'
response = requests.post( url, headers=headers, data=payload)

data = response.json()

print(response.status_code)
print(data)
# тестирование вставки темы
# Out:
# 200
# {'message': '', 'success': True}

# %% [markdown]
# ### Проверка ячеек в практике

# %%
import requests
import json

url = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_rows"
# url_save = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_save_work_lesson_subject"

cookie = 'ssuz_sessionid=7va4ga50ntdtaexw4gswr7zo2juwadks'
name = ''
les_id = 0

spisok_practicy = [
    {"group": "питпм_исп221а", "student_id": '70016', "group_id": '4649',"subject_id":'6132',"sub_group_id":'13664', "id":0},#1
    {"group": "питпм_исп221ав", "student_id": '70016', "group_id": '4649',"subject_id":'6132',"sub_group_id":'13665', "id":1},#2
    {"group": "питпм_исп221ав", "student_id": '70027', "group_id": '4659',"subject_id":'6132', "id":2},

    {"group": "рмп_исп320а", "student_id": '61655', "group_id": '4078',"subject_id":"6133","sub_group_id":'12601', "id":3},
    {"group": "рмп_исп320ав", "student_id": '61655', "group_id": '4078',"subject_id":"6133","sub_group_id":'12602', "id":4},
    {"group": "рмп_исп320ав", "student_id": '61683', "group_id": '4079',"subject_id":"6133", "id":5},

    {"group": "питпм_исп320п", "student_id": '61684', "group_id": '4080',"subject_id":"6132","sub_group_id":'12640', "id":6},
    {"group": "питпм_исп320пв", "student_id": '61684', "group_id": '4080',"subject_id":"6132","sub_group_id":'12641', "id":7},
    {"group": "питпм_исп320пв", "student_id": '61709', "group_id": '4081',"subject_id":"6132", "id":8},

    {"group": "ркис_исп320р", "student_id": '61712', "group_id": '4086',"subject_id":"6189","sub_group_id":'11776', "id":9},
    {"group": "ркис_исп320рв", "student_id": '61712', "group_id": '4086',"subject_id":"6189","sub_group_id":'11777', "id":10},
    {"group": "ркис_исп320рв", "student_id": '61680', "group_id": '4087',"subject_id":"6189", "id":11},

    {"group": "тис_исп320р", "student_id": '61712', "group_id": '4086',"subject_id":"6190","sub_group_id":'12654', "id":12},
    {"group": "тис_исп320рв", "student_id": '61712', "group_id": '4086',"subject_id":"6190","sub_group_id":'12655', "id":13},
    {"group": "тис_исп320рв", "student_id": '61680', "group_id": '4087',"subject_id":"6190", "id":14},

    {"group": "опбд_сис221", "student_id": '69973', "group_id": '4644',"subject_id":"5548","sub_group_id":'13640', "id":15},
    {"group": "опбд_сис221в", "student_id": '69973', "group_id": '4644',"subject_id":"5548","sub_group_id":'13641', "id":16},
    {"group": "опбд_сис221в", "student_id": '69998', "group_id": '4653',"subject_id":"5548", "sub_group_id":'13641',"id":17},

    {"group": "обвп_исп419р", "student_id": '48698', "group_id": '2848',"subject_id":"8010","sub_group_id":'13379', "id":18},
    {"group": "обвп_исп419рв", "student_id": '48698', "group_id": '2848',"subject_id":"8010","sub_group_id":'13380', "id":19},
    {"group": "обвп_исп419рв", "student_id": '49324', "group_id": '2945',"subject_id":"8010", "id":20},
]

spisok = spisok_practicy
v = 9

payload = {
    "unit_id": 22,
    "period_id":	30,
    "date_from":	"2022-09-01T00:00:00",
    "date_to":	"23.11.2022",
    "practical":	"1",
    "slave_mode":	"1",
    "month":	"",
    "group_id":	spisok[v]['group_id'],
    "subject":	"0",
    "subject_gen_pr_id":	"0",
    "exam_subject_id":	"0",
    "subject_sub_group_obj":  '',
    "subject_id":	spisok[v]['subject_id'],
}

# ii = v
if (spisok[v]['id']+1) %3 ==0:
  payload["subject_sub_group_obj"] = "{\"subject_id\": "+spisok[v]['subject_id']+"}"
else:
  payload["subject_sub_group_obj"] = "{\"subject_id\": "+spisok[v]['subject_id']+", \"sub_group_id\": "+spisok[v]['sub_group_id']+"}"
# print(payload)
headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}

response = requests.post(url, headers=headers, data=payload)
data = response.json()
print(data['rows'][0]['student_name'],spisok_practicy[v]['group'])

rows = data['rows'][0]['lessons']
for i in rows:
  print(i['id'],i['date'])
# Out:
# Ашапатов Николай Алексеевич ркис_исп320р
# 2934863 27.10.2022
# 2934990 27.10.2022
# 2934961 27.10.2022
# 2935019 27.10.2022
# 2942525 29.10.2022
# 2942757 29.10.2022
# 2950863 02.11.2022
# 2950983 02.11.2022
# 2950942 02.11.2022
# 2951024 02.11.2022
# 2954598 03.11.2022
# 2954736 03.11.2022
# 2954670 03.11.2022
# 2954767 03.11.2022
# 2958987 05.11.2022
# 2959116 05.11.2022
# 2959028 05.11.2022
# 2959137 05.11.2022
# 2962413 08.11.2022
# 2962445 08.11.2022
# 2962353 08.11.2022
# 2962477 08.11.2022
# 2962300 08.11.2022
# 2962515 08.11.2022
# 2965880 09.11.2022
# 2966079 09.11.2022
# 2965920 09.11.2022
# 2966119 09.11.2022
# 2965960 09.11.2022
# 2966000 09.11.2022
# 2969233 10.11.2022
# 2969278 10.11.2022
# 2969267 10.11.2022
# 2969289 10.11.2022
# 2977540 12.11.2022
# 2977620 12.11.2022
# 2977476 12.11.2022
# 2977657 12.11.2022
# 2984752 16.11.2022
# 2984912 16.11.2022
# 2984845 16.11.2022
# 2984951 16.11.2022
# 2984791 16.11.2022
# 2984993 16.11.2022

# %% [markdown]
# ### Проверка ячеек теория

# %%
import requests
import json

url = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_rows"

cookie = 'ssuz_sessionid=li2tlhtjj8f90adwti8n63unt7it82th'
name = ''

spisok = [
    {"group": "питпм_исп221а", "student_id": 70002, "group_id": 4649,"subject_id":"6132", "id":0},#0
    {"group": "питпм_исп221ав", "student_id": 70027, "group_id": 4659,"subject_id":"6132", "id":1},#1
    {"group": "рмп_исп320а", "student_id": 61655, "group_id": 4078,"subject_id":"6133", "id":2},#2
    {"group": "рмп_исп320ав", "student_id": 61683, "group_id": 4079,"subject_id":"6133", "id":3},#3
    {"group": "питпм_исп320п", "student_id": 61684, "group_id": 4080,"subject_id":"6132", "id":4},#4
    {"group": "питпм_исп320пв", "student_id": 61709, "group_id": 4081,"subject_id":"6132", "id":5},#5
    {"group": "ркис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6189", "id":6},#6
    {"group": "тис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6190", "id":7},#7
    {"group": "ркис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6189", "id":8},#8
    {"group": "тис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6190", "id":9},#9
    {"group": "опбд_сис221", "student_id": 69973, "group_id": 4644,"subject_id":"5548", "id":10},#10
    {"group": "опбд_сис221в", "student_id": 69998, "group_id": 4653,"subject_id":"5548", "id":11},#11
    {"group": "обвп_исп419р", "student_id": 48698, "group_id": 2848,"subject_id":"8010", "id":12},#12
    {"group": "обвп_исп419рв", "student_id": 49324, "group_id": 2945,"subject_id":"8010", "id":13},#13
]
v = 6

payload = {
    "unit_id": 22,
    "period_id":	30,
    "date_from":	"2022-09-01T00:00:00",
    "date_to":	"03.11.2022",
    "practical":	"",
    "slave_mode":	"1",
    "month":	"",
    "group_id":	spisok[v]['group_id'],
    "subject":	"0",
    "subject_gen_pr_id":	"0",
    "exam_subject_id":	"0",
    "subject_sub_group_obj":	"{\"subject_id\": "+spisok[v]['subject_id']+"}",
    "subject_id":	spisok[v]['subject_id'],
    "view_lessons":	"false"
}

headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}


response = requests.post(url, headers=headers, data=payload)
data = response.json()
print(data['rows'][0]['student_name'])

rows = data['rows'][0]['lessons']
for i in rows:
  print(i['id'],i['date'])
# Out:
# Ашапатов Николай Алексеевич
# 2786553 01.09.2022
# 2786601 01.09.2022
# 2848265 03.10.2022
# 2848550 03.10.2022
# 2848315 03.10.2022
# 2848600 03.10.2022
# 2848441 03.10.2022
# 2848631 03.10.2022
# 2852337 04.10.2022
# 2852413 04.10.2022
# 2865161 07.10.2022
# 2865256 07.10.2022
# 2869905 10.10.2022
# 2869953 10.10.2022
# 2889640 14.10.2022
# 2889881 14.10.2022
# 2889697 14.10.2022
# 2889933 14.10.2022
# 2934896 27.10.2022
# 2935051 27.10.2022
# 2950804 02.11.2022
# 2951069 02.11.2022

# %% [markdown]
# ## Выставление тем в журнал отдельно, Теория

# %%
import requests
cookie = 'ssuz_sessionid=58y9vdyy1whu0hcel3wjmv4s96gcov0h'

diir = 'D:\\Desktop\\Desktop\\Пары\\2022-2023\\_журнал\\txt\\лекции'#input('Какя директория: ')
spisok = [
    {"group": "питпм_исп221а", "student_id": 70002, "group_id": 4649,"subject_id":"6132", "id":0},#0
    {"group": "питпм_исп221ав", "student_id": 70027, "group_id": 4659,"subject_id":"6132", "id":1},#1
    {"group": "рмп_исп320а", "student_id": 61655, "group_id": 4078,"subject_id":"6133", "id":2},#2
    {"group": "рмп_исп320ав", "student_id": 61683, "group_id": 4079,"subject_id":"6133", "id":3},#3
    {"group": "питпм_исп320п", "student_id": 61684, "group_id": 4080,"subject_id":"6132", "id":4},#4
    {"group": "питпм_исп320пв", "student_id": 61709, "group_id": 4081,"subject_id":"6132", "id":5},#5
    {"group": "ркис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6189", "id":6},#6
    {"group": "тис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6190", "id":7},#7
    {"group": "ркис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6189", "id":8},#8
    {"group": "тис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6190", "id":9},#9
    {"group": "опбд_сис221", "student_id": 69973, "group_id": 4644,"subject_id":"5548", "id":10},#10
    {"group": "опбд_сис221в", "student_id": 69998, "group_id": 4653,"subject_id":"5548", "id":11},#11
    # {"group": "обвп_исп419р", "student_id": 48698, "group_id": 2848,"subject_id":"8010", "id":12},#12
    # {"group": "обвп_исп419рв", "student_id": 49324, "group_id": 2945,"subject_id":"8010", "id":13},#13
]

headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}

dates = '13.11.2022'
url_tab_rows = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_rows"
url_save = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_save_work_lesson_subject"


for name in [spisok[8]]:
  payload_tab_rows = {
    "unit_id": 22,
    "period_id":	30,
    "date_from":	"2022-09-01T00:00:00",
    "date_to":	dates,
    "practical":	"",
    "slave_mode":	"",
    "month":	"",
    "group_id":	name['group_id'],
    "subject":	"0",
    "subject_gen_pr_id":	"0",
    "exam_subject_id":	"0",
    "subject_sub_group_obj":	"{\"subject_id\": "+name['subject_id']+"}",
    "subject_id":	name['subject_id'],
    "view_lessons":	"false"
}
  response = requests.post(url_tab_rows, headers=headers, data=payload_tab_rows)
  # подучаем все столбцы
  # так как выдаёт всех студентов со всеми столбцами(попахивает бредом)
  # поэтому мы берём 0 элемент
  data = response.json()
  rows = data['rows'][0]['lessons']
  
  with open(diir+"\\rasp_"+name['group']+'.txt', encoding="utf-8") as file:
    # считываем строчки из файла
    try:
      lines = file.readlines()
      for i in range(len(lines)):
          name_lessons = lines[i]
          # print(name)
          les_id = rows[i]['id']
          # print(les_id,name)
          payload_save = {
              "lesson_id": les_id,
              "student_id": name['student_id'],
              "unit_id": "22",
              "period_id": "30",
              "date_from": "2022-09-01T00:00:00",
              "date_to": dates,
              "practical": "",
              "slave_mode": "1",
              "month": "",
              "group_id": name['group_id'],
              "subject": "0",
              "subject_gen_pr_id": "0",
              "exam_subject_id": "0",
              "subject_sub_group_obj":	"{\"subject_id\": "+name['subject_id']+"}",
              "subject_id": name['subject_id'],
              "view_lessons": "false",
              "lesson_subject": name_lessons
          }

          response = requests.post(url_save, headers=headers, data=payload_save)
          data = response.json()
          print(name['group'])
          print(i, response.status_code, data)

          # print(lines[i], rows[i]['id'])
      #   text =i.rstrip()
      #   print(text)
    except Exception as e:
        print(e)

    finally:
        file.close()
        print()
# Out:
# ркис_исп320рв
# 0 200 {'message': '', 'success': True}
# ркис_исп320рв
# 1 200 {'message': '', 'success': True}
# ркис_исп320рв
# 2 200 {'message': '', 'success': True}
# ркис_исп320рв
# 3 200 {'message': '', 'success': True}
# ркис_исп320рв
# 4 200 {'message': '', 'success': True}
# ркис_исп320рв
# 5 200 {'message': '', 'success': True}
# ркис_исп320рв
# 6 200 {'message': '', 'success': True}
# ркис_исп320рв
# 7 200 {'message': '', 'success': True}
# ркис_исп320рв
# 8 200 {'message': '', 'success': True}
# ркис_исп320рв
# 9 200 {'message': '', 'success': True}
# ркис_исп320рв
# 10 200 {'message': '', 'success': True}
# ркис_исп320рв
# 11 200 {'message': '', 'success': True}
# ркис_исп320рв
# 12 200 {'message': '', 'success': True}
# ркис_исп320рв
# 13 200 {'message': '', 'success': True}
# ркис_исп320рв
# 14 200 {'message': '', 'success': True}
# ркис_исп320рв
# 15 200 {'message': '', 'success': True}
# ркис_исп320рв
# 16 200 {'message': '', 'success': True}
# ркис_исп320рв
# 17 200 {'message': '', 'success': True}
# ркис_исп320рв
# 18 200 {'message': '', 'success': True}
# ркис_исп320рв
# 19 200 {'message': '', 'success': True}
# ркис_исп320рв
# 20 200 {'message': '', 'success': True}
# ркис_исп320рв
# 21 200 {'message': '', 'success': True}
# list index out of range

# %% [markdown]
# ## Выставление тем в журнал отдельно, практика

# %%
import requests
cookie = 'ssuz_sessionid=ssuz_sessionid'

diir = 'D:\\Desktop\\Desktop\\Пары\\2022-2023\\_журнал\\txt\\лекции'#input('Какя директория: ')

headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}

dates = '06.12.2022'

url_tab_rows = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_rows"
url_save = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_save_work_lesson_subject"

spisok_practicy = [
    {"group": "питпм_исп221а", "student_id": '70016', "group_id": '4649',"subject_id":'6132',"sub_group_id":'13664', "id":0},#1
    {"group": "питпм_исп221ав", "student_id": '70016', "group_id": '4649',"subject_id":'6132',"sub_group_id":'13665', "id":1},#2
    {"group": "питпм_исп221ав", "student_id": '70027', "group_id": '4659',"subject_id":'6132', "id":2},

    {"group": "рмп_исп320а", "student_id": '61655', "group_id": '4078',"subject_id":"6133","sub_group_id":'12601', "id":3},
    {"group": "рмп_исп320ав", "student_id": '61655', "group_id": '4078',"subject_id":"6133","sub_group_id":'12602', "id":4},
    {"group": "рмп_исп320ав", "student_id": '61683', "group_id": '4079',"subject_id":"6133", "id":5},

    {"group": "питпм_исп320п", "student_id": '61684', "group_id": '4080',"subject_id":"6132","sub_group_id":'12640', "id":6},
    {"group": "питпм_исп320пв", "student_id": '61684', "group_id": '4080',"subject_id":"6132","sub_group_id":'12641', "id":7},
    {"group": "питпм_исп320пв", "student_id": '61709', "group_id": '4081',"subject_id":"6132", "id":8},

    {"group": "ркис_исп320р", "student_id": '61712', "group_id": '4086',"subject_id":"6189","sub_group_id":'11776', "id":9},
    {"group": "ркис_исп320рв", "student_id": '61712', "group_id": '4086',"subject_id":"6189","sub_group_id":'11777', "id":10},
    {"group": "ркис_исп320рв", "student_id": '61680', "group_id": '4087',"subject_id":"6189", "id":11},

    {"group": "тис_исп320р", "student_id": '61712', "group_id": '4086',"subject_id":"6190","sub_group_id":'12654', "id":12},
    {"group": "тис_исп320рв", "student_id": '61712', "group_id": '4086',"subject_id":"6190","sub_group_id":'12655', "id":13},
    {"group": "тис_исп320рв", "student_id": '61680', "group_id": '4087',"subject_id":"6190", "id":14},

    {"group": "опбд_сис221", "student_id": '69973', "group_id": '4644',"subject_id":"5548","sub_group_id":'13640', "id":15},
    {"group": "опбд_сис221в", "student_id": '69973', "group_id": '4644',"subject_id":"5548","sub_group_id":'13641', "id":16},
    {"group": "опбд_сис221в", "student_id": '69998', "group_id": '4653',"subject_id":"5548", "sub_group_id":'13641',"id":17},

    # {"group": "обвп_исп419р", "student_id": '48698', "group_id": '2848',"subject_id":"8010","sub_group_id":'13379', "id":18},
    # {"group": "обвп_исп419рв", "student_id": '48698', "group_id": '2848',"subject_id":"8010","sub_group_id":'13380', "id":19},
    # {"group": "обвп_исп419рв", "student_id": '49324', "group_id": '2945',"subject_id":"8010", "id":20},
]

def payload_rows_practicy(dates,group_id,subject_id,sub_group_id):
  payload = {
    "unit_id": 22,
    "period_id":	30,
    "date_from":	"2022-09-01T00:00:00",
    "date_to":	dates,
    "practical":	"1",
    "slave_mode":	"1",
    "month":	"",
    "group_id":	group_id,
    "subject":	"0",
    "subject_gen_pr_id":	"0",
    "exam_subject_id":	"0",
    "subject_sub_group_obj": "",
    "subject_id":	subject_id,
    # "view_lessons":	"false"
  }
  if sub_group_id==0:
    payload["subject_sub_group_obj"] = "{\"subject_id\": "+subject_id+"}"
  else:
    payload["subject_sub_group_obj"] = "{\"subject_id\": "+subject_id+", \"sub_group_id\": "+sub_group_id+"}"
  return payload


def payload_rows_practicy_save_tema(les_id,student_id,dates,group_id,subject_id,sub_group_id,name_lessons):
  payload =  {
              "lesson_id": les_id,
              "student_id": student_id,
              "unit_id": "22",
              "period_id": "30",
              "date_from": "2022-09-01T00:00:00",
              "date_to": dates,
              "practical": "1",
              "slave_mode": "1",
              "month": "",
              "group_id": group_id,
              "subject": "0",
              "subject_gen_pr_id": "0",
              "exam_subject_id": "0",
              "subject_sub_group_obj":	"",#{\"subject_id\": "+name['subject_id']+"}",
              "subject_id": subject_id,
              "view_lessons": "false",
              "lesson_subject": name_lessons
              }
  if sub_group_id==0:
    payload["subject_sub_group_obj"] = "{\"subject_id\": "+subject_id+"}"
  else:
    payload["subject_sub_group_obj"] = "{\"subject_id\": "+subject_id+", \"sub_group_id\": "+sub_group_id+"}"
  return payload
  
for el in [spisok_practicy[15]]:
    payload = payload_rows_practicy(
                                    dates,el["group_id"],
                                    el["subject_id"],
                                    0 if (el['id']+1)%3==0 else el["sub_group_id"]
                                  )

    response = requests.post(url_tab_rows, headers=headers, data=payload)

    data = response.json()
    print(data['rows'][0]['student_name'],el['group'])

    rows = data['rows'][0]['lessons']
    # print(rows)
    # return 0
    with open(diir+"\\rasp_"+el['group']+'.txt', encoding="utf-8") as file:
    # считываем строчки из файла
      try:
        lines = file.readlines()
        for i in range(len(lines)):
            name_lessons = lines[i]
            # print(name)
            les_id = rows[i]['id']
            # print(les_id,name)
            payload_save = payload_rows_practicy_save_tema(
                            les_id,el['student_id'],
                            dates,el['group_id'],
                            el['subject_id'],
                            0 if (el['id']+1)%3==0 else el["sub_group_id"],
                            name_lessons
                          )
            
            # print(payload_save)
            response = requests.post(url_save, headers=headers, data=payload_save)
            data = response.json()
            print(el['group'])
            print(i, response.status_code, data)

          
      except Exception as e:
          print(1,e)

      finally:
          file.close()
          print()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# d:\Program Files\Python\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# d:\Program Files\Python\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# d:\Program Files\Python\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# d:\Program Files\Python\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# C:\Temp/ipykernel_9040/1277711819.py in <module>
#     108     response = requests.post(url_tab_rows, headers=headers, data=payload)
#     109
# --> 110     data = response.json()
#     111     print(data['rows'][0]['student_name'],el['group'])
#     112
#
# d:\Program Files\Python\lib\site-packages\requests\models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## закрытие теории

# %%
import requests
cookie = 'ssuz_sessionid=li2tlhtjj8f90adwti8n63unt7it82th'

diir = 'D:\\Desktop\\Desktop\\Пары\\2022-2023\\_журнал\\txt\\лекции'#input('Какя директория: ')
spisok = [
    {"group": "питпм_исп221а", "student_id": 70002, "group_id": 4649,"subject_id":"6132", "id":0},#0
    {"group": "питпм_исп221ав", "student_id": 70027, "group_id": 4659,"subject_id":"6132", "id":1},#1
    {"group": "рмп_исп320а", "student_id": 61655, "group_id": 4078,"subject_id":"6133", "id":2},#2
    {"group": "рмп_исп320ав", "student_id": 61683, "group_id": 4079,"subject_id":"6133", "id":3},#3
    {"group": "питпм_исп320п", "student_id": 61684, "group_id": 4080,"subject_id":"6132", "id":4},#4
    {"group": "питпм_исп320пв", "student_id": 61709, "group_id": 4081,"subject_id":"6132", "id":5},#5
    {"group": "ркис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6189", "id":6},#6
    {"group": "тис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6190", "id":7},#7
    {"group": "ркис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6189", "id":8},#8
    {"group": "тис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6190", "id":9},#9
    {"group": "опбд_сис221", "student_id": 69973, "group_id": 4644,"subject_id":"5548", "id":10},#10
    {"group": "опбд_сис221в", "student_id": 69998, "group_id": 4653,"subject_id":"5548", "id":11},#11
    # {"group": "обвп_исп419р", "student_id": 48698, "group_id": 2848,"subject_id":"8010", "id":12},#12
    # {"group": "обвп_исп419рв", "student_id": 49324, "group_id": 2945,"subject_id":"8010", "id":13},#13
]

headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}

dates = '13.11.2022'
url_close = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_close_lesson_action"
url_tab_rows = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_rows"


for name in [spisok[5]]:
  payload_tab_rows = {
    "unit_id": 22,
    "period_id":	30,
    "date_from":	"2022-09-01T00:00:00",
    "date_to":	dates,
    "practical":	"",
    "slave_mode":	"",
    "month":	"",
    "group_id":	name['group_id'],
    "subject":	"0",
    "subject_gen_pr_id":	"0",
    "exam_subject_id":	"0",
    "subject_sub_group_obj":	"{\"subject_id\": "+name['subject_id']+"}",
    "subject_id":	name['subject_id'],
    "view_lessons":	"false"
}
  response = requests.post(url_tab_rows, headers=headers, data=payload_tab_rows)
  # подучаем все столбцы
  # так как выдаёт всех студентов со всеми столбцами(попахивает бредом)
  # поэтому мы берём 0 элемент
  data = response.json()
  rows = data['rows'][0]['lessons']
  
  with open(diir+"\\rasp_"+name['group']+'.txt', encoding="utf-8") as file:
    # считываем строчки из файла
    try:
      lines = file.readlines()
      for i in range(len(lines)):
          name_lessons = lines[i]
          # print(name)
          les_id = rows[i]['id']
          # print(les_id,name)
          payload_save = {
              "lesson_id": les_id,
              "student_id": name['student_id'],
              "unit_id": "22",
              "period_id": "30",
              "date_from": "2022-09-01T00:00:00",
              "date_to": dates,
              "practical": "",
              "slave_mode": "1",
              "month": "",
              "group_id": name['group_id'],
              "subject": "0",
              "subject_gen_pr_id": "0",
              "exam_subject_id": "0",
              "subject_sub_group_obj":	"{\"subject_id\": "+name['subject_id']+"}",
              "subject_id": name['subject_id'],
              # "view_lessons": "false",
              # "lesson_subject": name_lessons
          }

          response = requests.post(url_close, headers=headers, data=payload_save)
          data = response.json()
          print(name['group'])
          print(i, response.status_code, data)

          # print(lines[i], rows[i]['id'])
      #   text =i.rstrip()
      #   print(text)
    except Exception as e:
        print(e)

    finally:
        file.close()
        print()
# Out:
# питпм_исп320пв
# 0 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 1 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 2 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 3 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 4 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 5 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 6 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 7 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 8 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 9 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 10 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 11 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 12 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 13 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 14 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 15 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 16 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 17 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 18 200 {'message': 'Занятие успешно закрыто', 'success': True}
# питпм_исп320пв
# 19 200 {'message': 'Занятие успешно закрыто', 'success': True}
# list index out of range

# %%
import os
from dotenv import load_dotenv

load_dotenv()

DATES = os.getenv('DATES')
print(DATES)
# Out:
# 13.12.2022
