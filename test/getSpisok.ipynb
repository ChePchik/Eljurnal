# %%
import requests
import pprint

dates="31.12.2022"
cookie="ssuz_sessionid=y3h7voj7du6nkhj7a85abvwiuwlc0de6"
dates_from="2022-09-01T00:00:00"
url_tab_group = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_group_rows"

headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}

payload = {
    'slave_mode': '1',
    'empty_item': '1',
    'practical': '1',
    'unit_id': '22',
    'period_id': '30',
    'date_from': dates_from,
    'date_to': dates,
    'month': '',
    'filter': '',
  }

response = requests.post(url_tab_group, headers=headers, data=payload)
data = response.json()
pprint.pprint(data['rows'])
# Out:
# [{'id': 4649, 'name': 'ИСП-221а - 2 курс'},
#  {'id': 4659, 'name': 'ИСП-221ав - 2 курс'},
#  {'id': 4078, 'name': 'ИСП-320а - 3 курс'},
#  {'id': 4079, 'name': 'ИСП-320ав - 3 курс'},
#  {'id': 4080, 'name': 'ИСП-320п - 3 курс'},
#  {'id': 4081, 'name': 'ИСП-320пв - 3 курс'},
#  {'id': 4086, 'name': 'ИСП-320р - 3 курс'},
#  {'id': 4087, 'name': 'ИСП-320рв - 3 курс'},
#  {'id': 2848, 'name': 'ИСП-419р - 4 курс'},
#  {'id': 2945, 'name': 'ИСП-419рв - 4 курс'},
#  {'id': 4644, 'name': 'СИС-221 - 2 курс'},
#  {'id': 4653, 'name': 'СИС-221в - 2 курс'}]

# %% [markdown]
# Получение групп

# %%
import requests
import pprint

dates="31.12.2022"
# cookie="ssuz_sessionid=wxlpgb69uumcnin2y8pd41d31r62oyl5"
dates_from="2022-09-01T00:00:00"
url_tab_subject = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_subject_rows"

headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}
id = 4649
payload = {
    'start': '0',
    'limit': '50',
    'practical': '1',
    'unit_id': '22',
    'period_id': '30',
    'date_from': dates_from,
    'date_to': dates,
    'slave_mode': '1',
    'm3_window_id': 'cmp_fdd8d53e',
    'filter': '',
    'group_id': id,
  }

response = requests.post(url_tab_subject, headers=headers, data=payload)
data = response.json()
pprint.pprint(data,compact=True)
# Out:
# {'rows': [{'id': '{"subject_id": 6132, "sub_group_id": 13664}',
#            'name': 'Поддержка и тестирование программных модулей (ИСП-221а/1)'},
#           {'id': '{"subject_id": 6132, "sub_group_id": 13665}',
#            'name': 'Поддержка и тестирование программных модулей (ИСП-221а/2)'},
#           {'id': '{"subject_id": 6132}',
#            'name': 'Поддержка и тестирование программных модулей'}],
#  'total': 3}

# %% [markdown]
# Получение предмета группы

# %%
import requests
import pprint


dates="31.12.2022"
cookie="ssuz_sessionid=wxlpgb69uumcnin2y8pd41d31r62oyl5"
dates_from="2022-09-01T00:00:00"
url_tab_stident = 'https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_rows'

headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}
sub_id = str(6190)
payload = {
      'unit_id': '22',
      'period_id': '30',
      'date_from': dates_from,
      'date_to': dates,
      'practical': '',
      'slave_mode': '1',
      'month': '',
      'group_id': id,
      'subject': '0',
      'subject_gen_pr_id': '0',
      'exam_subject_id': '0',
      'subject_sub_group_obj': '{"subject_id": ' + sub_id + '}',
      'subject_id': sub_id
  }

response = requests.post(url_tab_stident, headers=headers, data=payload)
data = response.json()
# print(data['rows'][0]['student_id'])
pprint.pprint(data,compact=True)
# Out:
# {'rows': [{'annual_estimation': None,
#            'aver_period': '4.71',
#            'aver_subper_6190_399': '4.71',
#            'final_grade': None,
#            'index': 1,
#            'lessons': [{'attendance': {'value': ''},
#                         'attendance_name': 'attendance',
#                         'date': '02.09.2022',
#                         'id': 2787057,
#                         'species_id': 6,
#                         'work_1135011': {'comment': '',
#                                          'type_id_36_score': '4',
#                                          'type_id_36_score_comment': ''},
#                         'work_1135011_name': 'work_1135011'},
#                        {'attendance': {'value': ''},
#                         'attendance_name': 'attendance',
#                         'date': '02.09.2022',
#                         'id': 2787122,
#                         'species_id': 6},
#                        {'attendance': {'value': ''},
# ...

# %%
import re 
import requests
import os
from dotenv import load_dotenv
load_dotenv()
import spisok_student as s


url_tab_rows = "https://ssuz.vip.edu35.ru/actions/register/lessons_tab/lessons_tab_rows"
dates_from = os.getenv('DATES_FROM')
dates = os.getenv('DATES')
cookie = os.getenv('COOKIE')
diir = os.getenv('DIIR')

headers = {
    'Host': 'ssuz.vip.edu35.ru',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0',
    'Accept': '*/*',
    'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Cookie': cookie
}

spisok = [
	{'group': 'Поддержка и тестирование программных модулей ИСП-221а', 'student_id': 70002, 'group_id': 4649, 'subject_id': '6132', 'id': 0},
	{'group': 'Поддержка и тестирование программных модулей ИСП-221ав', 'student_id': 70027, 'group_id': 4659, 'subject_id': '6132', 'id': 1},

	{'group': 'Разработка мобильных приложений ИСП-320а', 'student_id': 61655, 'group_id': 4078, 'subject_id': '6133', 'id': 2},
	{'group': 'Разработка мобильных приложений ИСП-320ав', 'student_id': 61683, 'group_id': 4079, 'subject_id': '6133', 'id': 3},

	{'group': 'Поддержка и тестирование программных модулей ИСП-320п', 'student_id': 61684, 'group_id': 4080, 'subject_id': '6132', 'id': 4},
	{'group': 'Поддержка и тестирование программных модулей ИСП-320пв', 'student_id': 61709, 'group_id': 4081, 'subject_id': '6132', 'id': 5},
  
	{'group': 'Разработка кода информационных систем ИСП-320р', 'student_id': 61712, 'group_id': 4086, 'subject_id': '6189', 'id': 6},
	{'group': 'Разработка кода информационных систем ИСП-320рв', 'student_id': 61680, 'group_id': 4087, 'subject_id': '6189', 'id': 7},

	{'group': 'Тестирование информационных систем ИСП-320р', 'student_id': 61712, 'group_id': 4086, 'subject_id': '6190', 'id': 8},

	{'group': 'Тестирование информационных систем ИСП-320рв', 'student_id': 61680, 'group_id': 4087, 'subject_id': '6190', 'id': 9},

	{'group': 'Основы проектирования баз данных СИС-221', 'student_id': 69973, 'group_id': 4644, 'subject_id': '5548', 'id': 10},
	{'group': 'Основы проектирования баз данных СИС-221в', 'student_id': 69998, 'group_id': 4653, 'subject_id': '5548', 'id': 11},

	{'group': 'Обеспечение безопасности веб-приложений ИСП-419р', 'student_id': 48698, 'group_id': 2848, 'subject_id': '8010', 'id': 12},
	{'group': 'Обеспечение безопасности веб-приложений ИСП-419рв', 'student_id': 49324, 'group_id': 2945, 'subject_id': '8010', 'id': 13},

]
spisok2 = [
    {"group": "питпм_исп221а", "student_id": 70002, "group_id": 4649,"subject_id":"6132", "id":0},#0
    {"group": "питпм_исп221ав", "student_id": 70027, "group_id": 4659,"subject_id":"6132", "id":1},#1
    
    {"group": "рмп_исп320а", "student_id": 61655, "group_id": 4078,"subject_id":"6133", "id":2},#2
    {"group": "рмп_исп320ав", "student_id": 61683, "group_id": 4079,"subject_id":"6133", "id":3},#3
    {"group": "питпм_исп320п", "student_id": 61684, "group_id": 4080,"subject_id":"6132", "id":4},#4
    {"group": "питпм_исп320пв", "student_id": 61709, "group_id": 4081,"subject_id":"6132", "id":5},#5
    {"group": "ркис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6189", "id":6},#6
    {"group": "ркис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6189", "id":7},#8
    {"group": "тис_исп320р", "student_id": 61712, "group_id": 4086,"subject_id":"6190", "id":8},#7
    {"group": "тис_исп320рв", "student_id": 61680, "group_id": 4087,"subject_id":"6190", "id":9},#9
    {"group": "опбд_сис221", "student_id": 69973, "group_id": 4644,"subject_id":"5548", "id":10},#10
    {"group": "опбд_сис221в", "student_id": 69998, "group_id": 4653,"subject_id":"5548", "id":11},#11
    {"group": "обвп_исп419р", "student_id": 48698, "group_id": 2848,"subject_id":"8010", "id":12},#12
    {"group": "обвп_исп419рв", "student_id": 49324, "group_id": 2945,"subject_id":"8010", "id":13},#13
]



spisok_practicy2 = [
    {"group": "питпм_исп221а", "student_id": '70016', "group_id": '4649',"subject_id":'6132',"sub_group_id":'13664', "id":0},#1
    {"group": "питпм_исп221ав", "student_id": '70016', "group_id": '4649',"subject_id":'6132',"sub_group_id":'13665', "id":1},#2
    {"group": "питпм_исп221ав", "student_id": '70027', "group_id": '4659',"subject_id":'6132', "id":2},

    {"group": "рмп_исп320а", "student_id": '61655', "group_id": '4078',"subject_id":"6133","sub_group_id":'12601', "id":3},
    {"group": "рмп_исп320ав", "student_id": '61655', "group_id": '4078',"subject_id":"6133","sub_group_id":'12602', "id":4},
    {"group": "рмп_исп320ав", "student_id": '61683', "group_id": '4079',"subject_id":"6133", "id":5},

    {"group": "питпм_исп320п", "student_id": '61684', "group_id": '4080',"subject_id":"6132","sub_group_id":'12640', "id":6},
    {"group": "питпм_исп320пв", "student_id": '61684', "group_id": '4080',"subject_id":"6132","sub_group_id":'12641', "id":7},
    {"group": "питпм_исп320пв", "student_id": '61709', "group_id": '4081',"subject_id":"6132", "id":8},

    {"group": "ркис_исп320р", "student_id": '61712', "group_id": '4086',"subject_id":"6189","sub_group_id":'11776', "id":9},
    {"group": "ркис_исп320рв", "student_id": '61712', "group_id": '4086',"subject_id":"6189","sub_group_id":'11777', "id":10},
    {"group": "ркис_исп320рв", "student_id": '61680', "group_id": '4087',"subject_id":"6189", "id":11},

    {"group": "тис_исп320р", "student_id": '61712', "group_id": '4086',"subject_id":"6190","sub_group_id":'12654', "id":12},
    {"group": "тис_исп320рв", "student_id": '61712', "group_id": '4086',"subject_id":"6190","sub_group_id":'12655', "id":13},
    {"group": "тис_исп320рв", "student_id": '61680', "group_id": '4087',"subject_id":"6190", "id":14},

    {"group": "опбд_сис221", "student_id": '69973', "group_id": '4644',"subject_id":"5548","sub_group_id":'13640', "id":15},
    {"group": "опбд_сис221в", "student_id": '69973', "group_id": '4644',"subject_id":"5548","sub_group_id":'13641', "id":16},
    {"group": "опбд_сис221в", "student_id": '69998', "group_id": '4653',"subject_id":"5548", "sub_group_id":'13641',"id":17},

    {"group": "обвп_исп419р", "student_id": '48698', "group_id": '2848',"subject_id":"8010","sub_group_id":'13379', "id":18},
    {"group": "обвп_исп419рв", "student_id": '48698', "group_id": '2848',"subject_id":"8010","sub_group_id":'13380', "id":19},
    {"group": "обвп_исп419рв", "student_id": '49324', "group_id": '2945',"subject_id":"8010", "id":20},
]


spisok_practicy_3 = [
	{'group': 'Поддержка и тестирование программных модулей ИСП-221а', 'group_id': 4649, 'student_id': 70002, 'subject_id': '6132', 'sub_group_id': '13664', 'id': 0},
	{'group': 'Поддержка и тестирование программных модулей ИСП-221ав', 'group_id': 4649, 'student_id': 70002, 'subject_id': '6132', 'sub_group_id': '13665', 'id': 1},
	{'group': 'Поддержка и тестирование программных модулей ИСП-221ав', 'group_id': 4659, 'student_id': 70027, 'subject_id': '6132', 'id': 2},

	{'group': 'Разработка мобильных приложений ИСП-320а', 'group_id': 4078, 'student_id': 61655, 'subject_id': '6133', 'sub_group_id': '12601', 'id': 3},
	{'group': 'Разработка мобильных приложений ИСП-320ав', 'group_id': 4078, 'student_id': 61655, 'subject_id': '6133', 'sub_group_id': '12602', 'id': 4},
	{'group': 'Разработка мобильных приложений ИСП-320ав', 'group_id': 4079, 'student_id': 61683, 'subject_id': '6133', 'id': 5},

	{'group': 'Поддержка и тестирование программных модулей ИСП-320п', 'group_id': 4080, 'student_id': 61684, 'subject_id': '6132', 'sub_group_id': '12640', 'id': 6},
	{'group': 'Поддержка и тестирование программных модулей ИСП-320пв', 'group_id': 4080, 'student_id': 61684, 'subject_id': '6132', 'sub_group_id': '12641', 'id': 7},
	{'group': 'Поддержка и тестирование программных модулей ИСП-320пв', 'group_id': 4081, 'student_id': 61709, 'subject_id': '6132', 'id': 8},

	{'group': 'Разработка кода информационных систем ИСП-320р', 'group_id': 4086, 'student_id': 61712, 'subject_id': '6189', 'sub_group_id': '11776', 'id': 9},
	{'group': 'Разработка кода информационных систем ИСП-320рв', 'group_id': 4086, 'student_id': 61712, 'subject_id': '6189', 'sub_group_id': '11777', 'id': 10},
	{'group': 'Разработка кода информационных систем ИСП-320рв', 'group_id': 4087, 'student_id': 61680, 'subject_id': '6189', 'id': 11},

	{'group': 'Тестирование информационных систем ИСП-320р', 'group_id': 4086, 'student_id': 61712, 'subject_id': '6190', 'sub_group_id': '11777', 'id': 12},
	{'group': 'Тестирование информационных систем ИСП-320рв', 'group_id': 4086, 'student_id': 61712, 'subject_id': '6190', 'sub_group_id': '11778', 'id': 13},
	{'group': 'Тестирование информационных систем ИСП-320рв', 'group_id': 4087, 'student_id': 61680, 'subject_id': '6190', 'id': 14},

	{'group': 'Обеспечение безопасности веб-приложений ИСП-419р', 'group_id': 2848, 'student_id': 48698, 'subject_id': '8010', 'sub_group_id': '13379', 'id': 15},
	{'group': 'Обеспечение безопасности веб-приложений ИСП-419рв', 'group_id': 2848, 'student_id': 48698, 'subject_id': '8010', 'sub_group_id': '13380', 'id': 16},
	{'group': 'Обеспечение безопасности веб-приложений ИСП-419рв', 'group_id': 2945, 'student_id': 49324, 'subject_id': '8010', 'id': 17},

	{'group': 'Основы проектирования баз данных СИС-221', 'group_id': 4644, 'student_id': 69973, 'subject_id': '5548', 'sub_group_id': '13640', 'id': 18},
	{'group': 'Основы проектирования баз данных СИС-221в', 'group_id': 4644, 'student_id': 69973, 'subject_id': '5548', 'sub_group_id': '13641', 'id': 19},
	{'group': 'Основы проектирования баз данных СИС-221в', 'group_id': 4653, 'student_id': 69998, 'subject_id': '5548', 'id': 20},
]



def payload_rows_teory(dates,group_id,subject_id):
  payload = {
    "unit_id": 22,
    "period_id":	30,
    "date_from":dates_from,
    "date_to":	dates,
    "practical":	"",
    "slave_mode":	"1",
    "month":	"",
    "group_id":	group_id,
    "subject":	"0",
    "subject_gen_pr_id":	"0",
    "exam_subject_id":	"0",
    "subject_sub_group_obj":	"{\"subject_id\": "+subject_id+"}",
    "subject_id":	subject_id,
    "view_lessons":	"false"
  }
  return payload
  
def payload_rows_practicy(dates,group_id,subject_id,sub_group_id):
  payload = {
    "unit_id": 22,
    "period_id":	30,
    "date_from":dates_from,
    "date_to":	dates,
    "practical":	"1",
    "slave_mode":	"1",
    "month":	"",
    "group_id":	group_id,
    "subject":	"0",
    "subject_gen_pr_id":	"0",
    "exam_subject_id":	"0",
    "subject_sub_group_obj": "",
    "subject_id":	subject_id,
    # "view_lessons":	"false"
  }
  if sub_group_id==0:
    payload["subject_sub_group_obj"] = "{\"subject_id\": "+subject_id+"}"
  else:
    payload["subject_sub_group_obj"] = "{\"subject_id\": "+subject_id+", \"sub_group_id\": "+sub_group_id+"}"
  return payload

for el in [spisok_practicy_3[18]]:
      payload = payload_rows_practicy(
                                      dates,
                                      el["group_id"],
                                      el["subject_id"],
                                      0 if (el['id']+1)%3==0 else el["sub_group_id"]
                                    )
      # payload = payload_rows_teory(dates,el["group_id"],el["subject_id"])


      response = requests.post(url_tab_rows, headers=headers, data=payload)

      data = response.json()
      print(data['rows'][0]['student_name'],el['group'])

      rows = data['rows'][0]['lessons']
      for i in rows:
        print(i['id'],i['date'])
# Out:
# Бедина Марина Геннадьевна Основы проектирования баз данных СИС-221
# 2920359 24.10.2022
# 2920597 24.10.2022
# 2927664 25.10.2022
# 2927701 25.10.2022
# 2936923 28.10.2022
# 2937114 28.10.2022
# 3003203 24.11.2022
# 3003316 24.11.2022
# 3003231 24.11.2022
# 3003344 24.11.2022

# %%
spisok_practicy_1 = [
    {"group": "питпм_исп221а", "student_id": '70016', "group_id": '4649',"subject_id":'6132',"sub_group_id":'13664', "id":0},#1
    {"group": "питпм_исп221ав", "student_id": '70016', "group_id": '4649',"subject_id":'6132',"sub_group_id":'13665', "id":1},#2
    {"group": "питпм_исп221ав", "student_id": '70027', "group_id": '4659',"subject_id":'6132', "id":2},

    {"group": "рмп_исп320а", "student_id": '61655', "group_id": '4078',"subject_id":"6133","sub_group_id":'12601', "id":3},
    {"group": "рмп_исп320ав", "student_id": '61655', "group_id": '4078',"subject_id":"6133","sub_group_id":'12602', "id":4},
    {"group": "рмп_исп320ав", "student_id": '61683', "group_id": '4079',"subject_id":"6133", "id":5},

    {"group": "питпм_исп320п", "student_id": '61684', "group_id": '4080',"subject_id":"6132","sub_group_id":'12640', "id":6},
    {"group": "питпм_исп320пв", "student_id": '61684', "group_id": '4080',"subject_id":"6132","sub_group_id":'12641', "id":7},
    {"group": "питпм_исп320пв", "student_id": '61709', "group_id": '4081',"subject_id":"6132", "id":8},

    {"group": "ркис_исп320р", "student_id": '61712', "group_id": '4086',"subject_id":"6189","sub_group_id":'11776', "id":9},
    {"group": "ркис_исп320рв", "student_id": '61712', "group_id": '4086',"subject_id":"6189","sub_group_id":'11777', "id":10},
    {"group": "ркис_исп320рв", "student_id": '61680', "group_id": '4087',"subject_id":"6189", "id":11},

    {"group": "тис_исп320р", "student_id": '61712', "group_id": '4086',"subject_id":"6190","sub_group_id":'12654', "id":12},
    {"group": "тис_исп320рв", "student_id": '61712', "group_id": '4086',"subject_id":"6190","sub_group_id":'12655', "id":13},
    {"group": "тис_исп320рв", "student_id": '61680', "group_id": '4087',"subject_id":"6190", "id":14},

    {"group": "обвп_исп419р", "student_id": '48698', "group_id": '2848',"subject_id":"8010","sub_group_id":'13379', "id":15},
    {"group": "обвп_исп419рв", "student_id": '48698', "group_id": '2848',"subject_id":"8010","sub_group_id":'13380', "id":16},
    {"group": "обвп_исп419рв", "student_id": '49324', "group_id": '2945',"subject_id":"8010", "id":17},

     {"group": "опбд_сис221", "student_id": '69973', "group_id": '4644',"subject_id":"5548","sub_group_id":'13640', "id":18},
    {"group": "опбд_сис221в", "student_id": '69973', "group_id": '4644',"subject_id":"5548","sub_group_id":'13641', "id":19},
    {"group": "опбд_сис221в", "student_id": '69998', "group_id": '4653',"subject_id":"5548", "sub_group_id":'13641',"id":20},
]
spisok_practicy2 = [
	{'group': 'Поддержка и тестирование программных модулей ИСП-221а', 'group_id': 4649, 'student_id': 70002, 'subject_id': '6132', 'sub_group_id': '13664', 'id': 0},
	{'group': 'Поддержка и тестирование программных модулей ИСП-221ав', 'group_id': 4649, 'student_id': 70002, 'subject_id': '6132', 'sub_group_id': '13665', 'id': 1},
	{'group': 'Поддержка и тестирование программных модулей ИСП-221ав', 'group_id': 4659, 'student_id': 70027, 'subject_id': '6132', 'id': 2},

	{'group': 'Разработка мобильных приложений ИСП-320а', 'group_id': 4078, 'student_id': 61655, 'subject_id': '6133', 'sub_group_id': '12601', 'id': 3},
	{'group': 'Разработка мобильных приложений ИСП-320ав', 'group_id': 4078, 'student_id': 61655, 'subject_id': '6133', 'sub_group_id': '12602', 'id': 4},
	{'group': 'Разработка мобильных приложений ИСП-320ав', 'group_id': 4079, 'student_id': 61683, 'subject_id': '6133', 'id': 5},

	{'group': 'Поддержка и тестирование программных модулей ИСП-320п', 'group_id': 4080, 'student_id': 61684, 'subject_id': '6132', 'sub_group_id': '12640', 'id': 6},
	{'group': 'Поддержка и тестирование программных модулей ИСП-320пв', 'group_id': 4080, 'student_id': 61684, 'subject_id': '6132', 'sub_group_id': '12641', 'id': 7},
	{'group': 'Поддержка и тестирование программных модулей ИСП-320пв', 'group_id': 4081, 'student_id': 61709, 'subject_id': '6132', 'id': 8},

	{'group': 'Разработка кода информационных систем ИСП-320р', 'group_id': 4086, 'student_id': 61712, 'subject_id': '6189', 'sub_group_id': '11776', 'id': 9},
	{'group': 'Разработка кода информационных систем ИСП-320рв', 'group_id': 4086, 'student_id': 61712, 'subject_id': '6189', 'sub_group_id': '11777', 'id': 10},
	{'group': 'Разработка кода информационных систем ИСП-320рв', 'group_id': 4087, 'student_id': 61680, 'subject_id': '6189', 'id': 11},
	
  {'group': 'Тестирование информационных систем ИСП-320р', 'group_id': 4086, 'student_id': 61712, 'subject_id': '6190', 'sub_group_id': '11777', 'id': 12},
	{'group': 'Тестирование информационных систем ИСП-320рв', 'group_id': 4086, 'student_id': 61712, 'subject_id': '6190', 'sub_group_id': '11778', 'id': 13},
	{'group': 'Тестирование информационных систем ИСП-320рв', 'group_id': 4087, 'student_id': 61680, 'subject_id': '6190', 'id': 14},

	{'group': 'Обеспечение безопасности веб-приложений ИСП-419р', 'group_id': 2848, 'student_id': 48698, 'subject_id': '8010', 'sub_group_id': '13379', 'id': 15},
	{'group': 'Обеспечение безопасности веб-приложений ИСП-419рв', 'group_id': 2848, 'student_id': 48698, 'subject_id': '8010', 'sub_group_id': '13380', 'id': 16},
	{'group': 'Обеспечение безопасности веб-приложений ИСП-419рв', 'group_id': 2945, 'student_id': 49324, 'subject_id': '8010', 'id': 17},

	{'group': 'Основы проектирования баз данных СИС-221', 'group_id': 4644, 'student_id': 69973, 'subject_id': '5548', 'sub_group_id': '13641', 'id': 18},
	{'group': 'Основы проектирования баз данных СИС-221в', 'group_id': 4644, 'student_id': 69973, 'subject_id': '5548', 'sub_group_id': '13642', 'id': 19},
	{'group': 'Основы проектирования баз данных СИС-221в', 'group_id': 4653, 'student_id': 69998, 'subject_id': '5548', 'id': 20},
]

# spisok = s.spisok
# spisok_practicy = s.spisok_practicy
# spisok2 = s.spisok2
# spisok_practicy2 = s.spisok_practicy2
for x in spisok_practicy_1:
  for y in spisok_practicy2:
    if(x['id']==y['id']):
      print(x['id'])
      print(x['group'],y['group'])

      # if(x['student_id']!=y['student_id']):
      #   print('student_id')
      #   print(x['student_id'])
      #   print(y['student_id'])

      if(int(x['group_id'])!=int(y['group_id'])):
        print('group_id')
        print(x['group_id'])
        print(y['group_id'])

      if(int(x['subject_id'])!=int(y['subject_id'])):
        print('subject_id')
        print(x['subject_id'])
        print(y['subject_id'])

      if 'sub_group_id' in x and 'sub_group_id' in y:
        if(int(x['sub_group_id'])!=int(y['sub_group_id'])):
          print('sub_group_id')
          print(x['sub_group_id'])
          print(y['sub_group_id'])
# Out:
# 0
# питпм_исп221а Поддержка и тестирование программных модулей ИСП-221а
# 1
# питпм_исп221ав Поддержка и тестирование программных модулей ИСП-221ав
# 2
# питпм_исп221ав Поддержка и тестирование программных модулей ИСП-221ав
# 3
# рмп_исп320а Разработка мобильных приложений ИСП-320а
# 4
# рмп_исп320ав Разработка мобильных приложений ИСП-320ав
# 5
# рмп_исп320ав Разработка мобильных приложений ИСП-320ав
# 6
# питпм_исп320п Поддержка и тестирование программных модулей ИСП-320п
# 7
# питпм_исп320пв Поддержка и тестирование программных модулей ИСП-320пв
# 8
# питпм_исп320пв Поддержка и тестирование программных модулей ИСП-320пв
# 9
# ркис_исп320р Разработка кода информационных систем ИСП-320р
# 10
# ркис_исп320рв Разработка кода информационных систем ИСП-320рв
# 11
# ркис_исп320рв Разработка кода информационных систем ИСП-320рв
# 12
# тис_исп320р Тестирование информационных систем ИСП-320р
# sub_group_id
# 12654
# 11777
# 13
# тис_исп320рв Тестирование информационных систем ИСП-320рв
# ...

# %%
import json
lists = ['abc','bcd','dvd']

for x, i in enumerate(lists):
  print(x,i)

# i = {'id': 4649, 'name': 'ИСП-221а - 2 курс'}
# i['name'][:i['name'].index(' ')]


s = {'id': '{"subject_id": 5548, "sub_group_id": 13640}'}

# (s['id'][15:-1])
d = json.loads(s['id'])
d['subject_id']

# dict({})
# ['sub_group_id']
# Out:
# 0 abc
# 1 bcd
# 2 dvd
# 5548

# %%
data = [
  '1.1 г',
  '1.2 г',
  '1пг',
  '2.1 г',
  '2.2 г',
  '2пг',
  '3.1 г',
  '3.2 г',
  '3пг',
]
for x, i in enumerate(data):
  if data[x]:
    w = x if x % 2 == 1 else x + 1
    print(data[w])
# Out:
# 1.2 г
# 1.2 г
# 2.1 г
# 2.1 г
# 2пг
# 2пг
# 3.2 г
# 3.2 г
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Temp/ipykernel_6076/787550398.py in <module>
#      13   if data[x]:
#      14     w = x if x % 2 == 1 else x + 1
# ---> 15     print(data[w])
#
# IndexError: list index out of range

# %%
s = {'name': 'ИСП-221а - 2 курс'}
s['name'].index(' ')
# Out:
# 8
